# %% [markdown]
# # Plot of Knock Airport Weather
# ---
# This notebook contains the plots of different variables contained in the Knock Airport Weather dataset.

# %%
# Import Pandas
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://cli.fusio.net/cli/climate_data/webdata/hly4935.csv', skiprows= 23)
# Out:
# C:\Users\sndrd\AppData\Local\Temp\ipykernel_3836\988172736.py:1: DtypeWarning: Columns (2,10,12,14,15,16,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://cli.fusio.net/cli/climate_data/webdata/hly4935.csv', skiprows= 23)

# %%
df.head(10)
# Out:
#                 date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# 0  10-apr-1996 14:00    0  0.0      0  11.5      0   8.1    3.9    0.0     0
# 1  31-jul-1996 08:00    0  0.0      0  11.5      0  11.1   10.7    0.0     0
# 2  31-jul-1996 09:00    0  0.0      0  11.6      0  10.7    9.8    0.0     0
# 3  31-jul-1996 10:00    0  0.0      0  12.9      0  11.3    9.8    0.0     0
# 4  31-jul-1996 11:00    0  0.0      0  14.5      0  10.8    7.0    0.0     0
# 5  31-jul-1996 12:00    0  0.0      0  14.4      0  10.9    7.3    0.0     0
# 6  31-jul-1996 13:00    0  0.0      0  14.9      0  10.9    6.7    0.0     0
# 7  31-jul-1996 14:00    0  0.0      0  13.9      0  10.4    6.7    0.0     0
# 8  31-jul-1996 15:00    0  0.0      0  13.2      0  10.9    8.6    0.0     0
# 9  31-jul-1996 16:00    0  0.0      0  15.1      0  11.3    7.5    0.0     0
#
#    ... ind.3  wdsp ind.4  wddir  ww   w  sun    vis clht clamt
# 0  ...     0     0     0      0  25  81  0.0  35000   32     5
# 1  ...     0     0     0      0  25  82  0.0  40000   45     5
# 2  ...     0     0     0      0  80  81  0.0   8000   32     7
# 3  ...     0     0     0      0  25  82  0.0  28000   35     6
# 4  ...     0     0     0      0   2  11  0.0  40000   40     6
# 5  ...     0     0     0      0   1  82  0.0  40000   43     6
# 6  ...     0     0     0      0   2  11  0.0  40000   43     5
# 7  ...     0     0     0      0   2  11  0.0  50000   45     6
# 8  ...     0     0     0      0  25  82  0.0   8000   45     7
# 9  ...     0     0     0      0  25  82  0.0  35000   40     7
#
# [10 rows x 21 columns]

# %%
import pandas as pd

# Change the date into the DateTime format
df['date'] = pd.to_datetime(df['date'], format='%d-%b-%Y %H:%M')

df.head(10)
# Out:
#                  date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# 0 1996-04-10 14:00:00    0  0.0      0  11.5      0   8.1    3.9    0.0     0
# 1 1996-07-31 08:00:00    0  0.0      0  11.5      0  11.1   10.7    0.0     0
# 2 1996-07-31 09:00:00    0  0.0      0  11.6      0  10.7    9.8    0.0     0
# 3 1996-07-31 10:00:00    0  0.0      0  12.9      0  11.3    9.8    0.0     0
# 4 1996-07-31 11:00:00    0  0.0      0  14.5      0  10.8    7.0    0.0     0
# 5 1996-07-31 12:00:00    0  0.0      0  14.4      0  10.9    7.3    0.0     0
# 6 1996-07-31 13:00:00    0  0.0      0  14.9      0  10.9    6.7    0.0     0
# 7 1996-07-31 14:00:00    0  0.0      0  13.9      0  10.4    6.7    0.0     0
# 8 1996-07-31 15:00:00    0  0.0      0  13.2      0  10.9    8.6    0.0     0
# 9 1996-07-31 16:00:00    0  0.0      0  15.1      0  11.3    7.5    0.0     0
#
#    ... ind.3  wdsp ind.4  wddir  ww   w  sun    vis clht clamt
# 0  ...     0     0     0      0  25  81  0.0  35000   32     5
# 1  ...     0     0     0      0  25  82  0.0  40000   45     5
# 2  ...     0     0     0      0  80  81  0.0   8000   32     7
# 3  ...     0     0     0      0  25  82  0.0  28000   35     6
# 4  ...     0     0     0      0   2  11  0.0  40000   40     6
# 5  ...     0     0     0      0   1  82  0.0  40000   43     6
# 6  ...     0     0     0      0   2  11  0.0  40000   43     5
# 7  ...     0     0     0      0   2  11  0.0  50000   45     6
# 8  ...     0     0     0      0  25  82  0.0   8000   45     7
# 9  ...     0     0     0      0  25  82  0.0  35000   40     7
#
# [10 rows x 21 columns]

# %%
# Checking for gaps or missing values
df.iloc[157863]
# Out:
# date     2014-08-03 22:00:00
# ind                        0
# rain                     0.0
# ind.1                      0
# temp                    11.6
# ind.2                      0
# wetb                    10.7
# dewpt                    9.9
# vappr                   12.1
# rhum                      89
# msl                   1010.2
# ind.3                      2
# wdsp                       6
# ind.4                      2
# wddir                    280
# ww
# w
# sun                      0.0
# vis
# clht                       0
# clamt                      8
# Name: 157863, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Check what data types the columns are
print(df.dtypes)
# Out:
# date     datetime64[ns]
# ind               int64
# rain             object
# ind.1             int64
# temp            float64
# ind.2             int64
# wetb            float64
# dewpt           float64
# vappr           float64
# rhum              int64
# msl              object
# ind.3             int64
# wdsp             object
# ind.4             int64
# wddir            object
# ww               object
# w                object
# sun             float64
# vis              object
# clht             object
# clamt            object
# dtype: object

# %%
# Checking columns with object type to find invalid values
for col in df.select_dtypes(include='object').columns:
    print(f"Unique values in '{col}': {df[col].unique()[:10]}")  # Show first 10 unique values
# Out:
# Unique values in 'rain': ['0.0' '0.1' ' ' '1.0' '3.1' '0.7' '0.3' '0.6' '1.5' '3.3']
# Unique values in 'msl': ['1016.7' '1011.4' '1011.2' '1011.0' '1010.9' '1011.3' '1011.6' '1011.8'
#  '1011.1' '1011.5']
# Unique values in 'wdsp': ['0' '6' '8' '9' '7' '11' '13' '12' '14' '10']
# Unique values in 'wddir': ['0' '230' '240' '250' '260' '270' '280' '290' ' ' '300']
# Unique values in 'ww': ['25' '80' '2' '1' '21' '3' '11' '46' '47' '42']
# Unique values in 'w': ['81' '82' '11' '62' '22' '86' '42' '44' '41' ' ']
# Unique values in 'vis': ['35000' '40000' '8000' '28000' '50000' '30000' '25000' '22000' '7000'
#  '10000']
# Unique values in 'clht': ['32' '45' '35' '40' '43' '20' '0' '999' '50' '44']
# Unique values in 'clamt': ['5' '7' '6' '3' '4' '8' ' ' '2' '1' '0']

# %%
# Columns with spaces or special values to clean
columns_to_clean = ['rain', 'wddir', 'w', 'clamt', 'clht']

# Replace ' ' and 999 with NaN
df[columns_to_clean] = df[columns_to_clean].replace([' ', 999], np.nan)

# %%
# Convert the object columns to numeric
df[columns_to_clean] = df[columns_to_clean].apply(pd.to_numeric, errors='coerce')

# %%
# Replace NaN with 0
data = df.fillna(0)

# %%
print(data.dtypes)  # Confirm all columns are numeric
print(data.isnull().sum())  # Confirm no NaN values
# Out:
# date     datetime64[ns]
# ind               int64
# rain            float64
# ind.1             int64
# temp            float64
# ind.2             int64
# wetb            float64
# dewpt           float64
# vappr           float64
# rhum              int64
# msl              object
# ind.3             int64
# wdsp             object
# ind.4             int64
# wddir           float64
# ww               object
# w               float64
# sun             float64
# vis              object
# clht            float64
# clamt           float64
# dtype: object
# date     0
# ind      0
# rain     0
# ind.1    0
# temp     0
# ind.2    0
# wetb     0
# dewpt    0
# vappr    0
# rhum     0
# msl      0
# ind.3    0
# wdsp     0
# ind.4    0
# wddir    0
# ww       0
# w        0
# sun      0
# vis      0
# clht     0
# clamt    0
# dtype: int64

# %%
# List the columns that should be numeric
columns_to_convert = ['msl', 'wdsp', 'ww', 'vis']

# Convert columns to numeric (invalid values become NaN)
data[columns_to_convert] = data[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
print(data.dtypes)
# Out:
# date     datetime64[ns]
# ind               int64
# rain            float64
# ind.1             int64
# temp            float64
# ind.2             int64
# wetb            float64
# dewpt           float64
# vappr           float64
# rhum              int64
# msl             float64
# ind.3             int64
# wdsp            float64
# ind.4             int64
# wddir           float64
# ww              float64
# w               float64
# sun             float64
# vis             float64
# clht            float64
# clamt           float64
# dtype: object

# %%
data = data.fillna(0)

# %%
data.iloc[145454]
# Out:
# date     2013-03-04 21:00:00
# ind                        0
# rain                     0.0
# ind.1                      0
# temp                     3.2
# ind.2                      0
# wetb                     2.8
# dewpt                    2.2
# vappr                    7.1
# rhum                      93
# msl                   1007.1
# ind.3                      2
# wdsp                     7.0
# ind.4                      2
# wddir                  130.0
# ww                       0.0
# w                        0.0
# sun                      0.0
# vis                      0.0
# clht                     0.0
# clamt                    8.0
# Name: 145454, dtype: object

# %%
data.head(5)
# Out:
#                  date  ind  rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 0 1996-04-10 14:00:00    0   0.0      0  11.5      0   8.1    3.9    0.0
# 1 1996-07-31 08:00:00    0   0.0      0  11.5      0  11.1   10.7    0.0
# 2 1996-07-31 09:00:00    0   0.0      0  11.6      0  10.7    9.8    0.0
# 3 1996-07-31 10:00:00    0   0.0      0  12.9      0  11.3    9.8    0.0
# 4 1996-07-31 11:00:00    0   0.0      0  14.5      0  10.8    7.0    0.0
#
#    rhum  ...  ind.4  wddir    ww     w  sun      vis  clht  clamt         day  \
# 0     0  ...      0    0.0  25.0  81.0  0.0  35000.0  32.0    5.0  1996-04-10
# 1     0  ...      0    0.0  25.0  82.0  0.0  40000.0  45.0    5.0  1996-07-31
# 2     0  ...      0    0.0  80.0  81.0  0.0   8000.0  32.0    7.0  1996-07-31
# 3     0  ...      0    0.0  25.0  82.0  0.0  28000.0  35.0    6.0  1996-07-31
# 4     0  ...      0    0.0   2.0  11.0  0.0  40000.0  40.0    6.0  1996-07-31
#
#      month
# 0  1996-04
# 1  1996-07
# 2  1996-07
# 3  1996-07
# 4  1996-07
#
# [5 rows x 23 columns]

# %%
# Plot the temperatures from the new data frame
import matplotlib.pyplot as plt

plt.plot(data['date'], data['temp'], alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.title('The Temperature of Each Day')
plt.show()

# %%
# Get the mean temperature
data['day'] = data['date'].dt.date  # Extract only the date (no time)

grouped_data = data.groupby('day').mean()  # Calculate the mean for each day

grouped_data = grouped_data.reset_index()

# %%
grouped_data.head(10)
# Out:
#           day                date       ind      rain  ind.1       temp  \
# 0  1996-04-10 1996-04-10 14:00:00  0.000000  0.000000    0.0  11.500000
# 1  1996-07-31 1996-07-31 15:30:00  0.000000  0.000000    0.0  12.650000
# 2  1996-08-01 1996-08-01 11:30:00  0.833333  0.008333    0.0  11.666667
# 3  1996-08-02 1996-08-02 11:30:00  0.000000  0.012500    0.0  12.504167
# 4  1996-08-03 1996-08-03 11:30:00  0.000000  0.000000    0.0  14.266667
# 5  1996-08-04 1996-08-04 11:30:00  0.250000  0.004167    0.0  13.987500
# 6  1996-08-05 1996-08-05 11:30:00  0.000000  0.550000    0.0  11.520833
# 7  1996-08-06 1996-08-06 11:30:00  0.000000  0.004167    0.0  11.108333
# 8  1996-08-07 1996-08-07 11:30:00  0.083333  0.108333    0.0  12.633333
# 9  1996-08-08 1996-08-08 11:30:00  0.000000  0.150000    0.0  13.566667
#
#    ind.2       wetb      dewpt      vappr  ...  ind.3       wdsp  ind.4  \
# 0    0.0   8.100000   3.900000   0.000000  ...  0.000   0.000000  0.000
# 1    0.0  10.687500   8.693750   0.000000  ...  0.000   0.000000  0.000
# 2    0.0  10.370833   9.100000  11.108333  ...  2.125   9.541667  2.125
# 3    0.0  11.229167  10.045833  12.308333  ...  2.000   7.625000  2.000
# 4    0.0  12.395833  10.729167  12.904167  ...  2.000   6.666667  2.000
# 5    0.0  11.758333   9.754167  12.187500  ...  2.000  11.041667  2.000
# 6    0.0  11.133333  10.758333  12.979167  ...  2.000   8.000000  2.000
# 7    0.0   9.566667   7.958333  10.708333  ...  2.000  12.666667  2.000
# 8    0.0  11.783333  11.037500  13.329167  ...  2.000   7.125000  2.000
# 9    0.0  12.100000  10.762500  12.970833  ...  2.000  12.583333  2.000
#
#         wddir         ww          w       sun           vis        clht  \
# 0    0.000000  25.000000  81.000000  0.000000  35000.000000   32.000000
# 1    0.000000  14.000000  50.875000  0.000000  33375.000000   36.750000
# 2  241.666667  22.833333  49.208333  0.045833  28916.666667  114.166667
# 3  265.000000  19.125000  37.625000  4.695833  33291.666667   27.791667
# 4  220.000000   2.000000  11.000000  0.441667  51458.333333  133.875000
# 5  159.166667   8.750000  18.333333  0.283333  28991.666667  188.375000
# 6  281.666667  46.791667  59.208333  0.000000  12091.666667   25.000000
# 7  315.833333   2.791667  13.208333  0.250000  48125.000000  209.416667
# 8  203.750000  14.541667  31.500000  0.050000  27100.000000   63.833333
# 9  172.916667  19.500000  37.041667  4.695833  34041.666667  237.500000
#
#       clamt
# 0  5.000000
# 1  6.000000
# 2  6.500000
# 3  6.833333
# 4  6.250000
# 5  5.916667
# 6  7.875000
# 7  5.791667
# 8  7.125000
# 9  6.083333
#
# [10 rows x 22 columns]

# %%
# Plot the mean temperatures
import matplotlib.pyplot as plt

plt.plot(grouped_data['date'], grouped_data['temp'], alpha=0.5) 
plt.xlabel('Date')
plt.ylabel('Mean Temperature')
plt.title('The Mean Temperature of Each Day')
plt.show()
