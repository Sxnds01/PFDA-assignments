# %% [markdown]
# # Pie Chart
# ---
# This notebook contains 1000 people's email domains, separated into three categories - @example.com, @example.net and @example.org. A pie chart is created from these categories with the percentage or occurance for each domain.

# %%
import pandas as pd

# %%
df = pd.read_csv("people-1000.csv")

# %%
df
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
# Remove one of the index columns
df = pd.read_csv("people-1000.csv", header=None, index_col=0)
df
# Out:
#                      1           2          3       4  \
# 0
# Index          User Id  First Name  Last Name     Sex
# 1      8717bbf45cCDbEe      Shelia    Mahoney    Male
# 2      3d5AD30A4cD38ed          Jo     Rivers  Female
# 3      810Ce0F276Badec      Sheryl     Lowery  Female
# 4      BF2a889C00f0cE1     Whitney     Hooper    Male
# ...                ...         ...        ...     ...
# 996    fedF4c7Fd9e7cFa        Kurt     Bryant  Female
# 997    ECddaFEDdEc4FAB       Donna      Barry  Female
# 998    2adde51d8B8979E       Cathy   Mckinney  Female
# 999    Fb2FE369D1E171A    Jermaine     Phelps    Male
# 1000   8b756f6231DDC6e         Lee       Tran  Female
#
#                                    5                      6              7  \
# 0
# Index                          Email                  Phone  Date of birth
# 1                pwarner@example.org           857.139.8239     2014-01-27
# 2      fergusonkatherine@example.net        +1-950-759-8687     1931-07-26
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# creating dataframe
dataFrame = pd.DataFrame({
   "Email_domain": ['domain_com', 'domain_net', 'domain_org'],"Number_of_domains": [339, 320, 341]
})
colors = ['pink', 'steelblue', 'red']
explode = [0, 0, 0.1]

plt.pie(dataFrame["Number_of_domains"], labels = dataFrame["Email_domain"], autopct='%1.1f%%', startangle=90, explode = explode, shadow = True, colors = colors)

plt.title('Percentages of the Three different Email Domain Types')
plt.legend()
plt.show()

# %% [markdown]
# # References
# ---
# 1. Regex: https://ravi-chan.medium.com/beginners-guide-to-regex-in-pandas-308b79e477e6
# 2. Matplotlib Pie Chart: https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html#sphx-glr-gallery-pie-and-polar-charts-pie-features-py
# 3. W3schools Pie Chart: https://www.w3schools.com/python/matplotlib_pie_charts.asp
